# %%
print("Hola mundo")
# Out:
# Hola mundo

# %%
print('My name is Sara')
print('I live in Colombia')
print('I am a TI Analyst and I love what I do!')
# Out:
# My name is Sara
# I live in Colombia
# I am a TI Analyst and I love what I do!

# %%
def my_introduction():
    print('My name is Sara')
    print('I live in Colombia')
    print('I am a TI Analyst and I love what I do!')

# %%
my_introduction()
# Out:
# My name is Sara
# I live in Colombia
# I am a TI Analyst and I love what I do!

# %%
my_introduction()
# Out:
# My name is Sara
# I live in Colombia
# I am a TI Analyst and I love what I do!

# %%
def hello_world():
    print('Welcome to Python!')

print('This is outsude the function')
# Out:
# This is outsude the function

# %%
hello_world()
# Out:
# Welcome to Python!

# %%
def my_new_function():
    print('This is now defined')

my_new_function()
# Out:
# This is now defined

# %%
def wil_not_work_funcion():
print('This identatios is all wrong')
# Out:
#   Cell In[11], line 2
#     print('This identatios is all wrong')
#     ^
# IndentationError: expected an indented block after function definition on line 1

# %%
def wil_work_funcion():
    print('This identation is all right!')

    if 10 > 5:
        print("Well 10 is greater than 5")

# %%
wil_work_funcion()
# Out:
# This identation is all right!
# Well 10 is greater than 5

# %%
def a_more_complicated_function():
    for i in range(10):
        print("i is now: ", i)

# %%
a_more_complicated_function()
# Out:
# i is now:  0
# i is now:  1
# i is now:  2
# i is now:  3
# i is now:  4
# i is now:  5
# i is now:  6
# i is now:  7
# i is now:  8
# i is now:  9

# %%
def _Functions_Can_Be_NamedLikeThis_123():
    print("This works!")

_Functions_Can_Be_NamedLikeThis_123()
# Out:
# This works!

# %%
def 123this_does_not_work():
    print("This does not work")
# Out:
#   Cell In[18], line 1
#     def 123this_does_not_work():
#           ^
# SyntaxError: invalid decimal literal

# %%
def documented_function():
    """ This function does something that is well documented  """
    print("Hello")

# %%
documented_function
# Out:
# <function __main__.documented_function()>

# %%
# Acceder a la documentación de una funcion
documented_function.__doc__
# Out:
# ' This function does something that is well documented  '

# %%
another_function = documented_function

# %%
another_function
# Out:
# <function __main__.documented_function()>

# %%
another_function.__doc__
# Out:
# ' This function does something that is well documented  '

# %%
another_function()
# Out:
# Hello

# %%
documented_function()
# Out:
# Hello

# %%
name = "Sara"
city = "Medellin"

# %%
def introduction():
    print("My name is: ", name)
    print("I live in: ", city)

# %%
introduction()
# Out:
# My name is:  Sara
# I live in:  Medellin

# %%
name = "John"
city = "Toronto"

# %%
introduction()
# Out:
# My name is:  John
# I live in:  Toronto

# %%
name = "Sara"
city = "Seattle"

# %%
introduction()
# Out:
# My name is:  Sara
# I live in:  Seattle

# %%
"a" + 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 "a" + 2
#
# TypeError: can only concatenate str (not "int") to str

# %%
# Aunque en la definicion hay un error, no se evidencia, pues aquí no se invoca la funcion.
def function_with_error():
    result = "a" + 2

    print(result)

# %%
# El error se evidencia al invocar la funcion
function_with_error()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 2
#       1 # El error se evidencia al invocar la funcion
# ----> 2 function_with_error()
#
# Cell In[46], line 3, in function_with_error()
#       2 def function_with_error():
# ----> 3     result = "a" + 2
#       5     print(result)
#
# TypeError: can only concatenate str (not "int") to str
